# %%
#common imports
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import requests

# %matplotlib inline

# %%
#imports needed for Google Sheets
import gspread
from gspread_dataframe import get_as_dataframe, set_with_dataframe
from google.colab import auth
from google.auth import default

#verification from account for reading files you have access to.
auth.authenticate_user()
creds, _ = default()
from oauth2client.client import GoogleCredentials
gc = gspread.authorize(creds)

# %%
spreadsheet_id = "1gH8dn7mK1X9JwQH85RS5_Fv7nIb6lBChZY2QARqBMNU"
spreadsheet = gc.open_by_key(spreadsheet_id)
worksheet = spreadsheet.sheet1

# %%
df = pd.DataFrame(worksheet.get_all_records())

# %%
df
# Out:
#     1  10
# 0   2   9
# 1   3   8
# 2   4   7
# 3   5   6
# 4   6   5
# 5   7   4
# 6   8   3
# 7   9   2
# 8  10   1

# %%
#create a defined function to access OneDrive files
def download_file_using_requests(url, disk_location):
  r = requests.get(url, stream=True)
  if r.status_code == 200:
    with open(disk_location, 'wb') as f:
      for chunk in r.iter_content(1024):
        f.write(chunk)

# %%
# Google Sheets має спеціальний API для експорту CSV.
# Замість edit?gid=0 потрібно замінити на:
# /gviz/tq?tqx=out:csv&sheet=Sheet1
# original: https://docs.google.com/spreadsheets/d/1yOA111ZolOD3KVQ1Q7ry4YusuX2w0rwHlVNxGLjdfJM/edit?gid=0#gid=0
url      = 'https://docs.google.com/spreadsheets/d/1yOA111ZolOD3KVQ1Q7ry4YusuX2w0rwHlVNxGLjdfJM/gviz/tq?tqx=out:csv&sheet=Sheet1'

# %%
#downloading the file into this Colab notebook
download_file_using_requests(url, "file_2.xlsx")

# %%
df1 = pd.read_csv(url)

# %%
df1
# Out:
#     First  Second
# 0       1       a
# 1       2       b
# 2       3       c
# 3       4       g
# 4       5       d
# 5       6       a
# 6       7       h
# 7       8       t
# 8       9       t
# 9      10       t
# 10     11       a
# 11     12       y
# 12     13       u
# 13     14       i
# 14     15       a
# 15     16  Second
# 16     17       e
# 17     18       a
# 18     19       h

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = "/content/drive/My Drive/Colab Notebooks/Data1.xlsx"  # Оновіть шлях до файлу
df2 = pd.read_excel(file_path, engine="openpyxl")

# %%
df2.head()
# Out:
#    1   10
# 0   2   9
# 1   3   8
# 2   4   7
# 3   5   6
# 4   6   5

# %%
df.head()
# Out:
#    1  10
# 0  2   9
# 1  3   8
# 2  4   7
# 3  5   6
# 4  6   5
